# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table

# %%
image = np.loadtxt("astro_image (1).csv")

# %%
low, high = np.percentile(image, [1, 99])

plt.figure()
im = plt.imshow(image, vmin = low, vmax = high, cmap = "magma", origin = "lower")
plt.colorbar(im)

# %%
fit, ax = plt.subplots(1, 2)

# %% [markdown]
# 1) What are the column names in this dataset?

# %% [markdown]
# df.columns

# %% [markdown]
# This prints out all the columm names

# %% [markdown]
# What is the ramen style of the 27th entry?

# %%
table = Table.read("global_CCl4_MM.dat", format='ascii')

# %%
df = pd.DataFrame(table)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31380\2092666284.py in ?()
# ----> 1 df = pd.DataFrame(table)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
